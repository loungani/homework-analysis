# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
homework = pd.read_excel("Homework.xlsx")

# %%
homework.head()
# Out:
#       Class   Due Date Assignment Name     Status  Days Left  \
# 0  Stat 432 2018-01-18             HW1  Completed          0
# 1  Math 361 2018-01-25      Homework 1  Completed          0
# 2  Stat 432 2018-01-25             HW2  Completed          0
# 3    CS 350 2018-01-26      Homework 1    Skipped          0
# 4  Math 361 2018-02-01      Homework 2    Skipped          0
#
#   Estimated Difficulty  ~ Hours Invested  Raw Grade  Class Mean  Unnamed: 9  \
# 0              Not bad               7.0       0.84         NaN         NaN
# 1                 Hard               7.0       0.70         NaN         NaN
# 2              Not bad               3.0       1.16         NaN         NaN
# 3              Lengthy               1.0       0.00         NaN         NaN
# 4                 Hard               0.0       0.00         NaN         NaN
#
#    Hours of my Life Irretrievably Lost
# 0                                200.0
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN

# %%
def getCumHours(date):
    return data[data['Due Date']<=date]['~ Hours Invested'].sum()

# %%
fig, ax = plt.subplots(figsize=(16, 4))

plt.xkcd()

x = homework['Due Date']
i = 0

for c in homework['Class'].unique():
    data = homework[homework['Class'] == c]
    y = homework['Due Date'].apply(getCumHours)
    ax.plot(x, y, label = c)
    i = i + 1
    
plt.annotate(
    'GRADUATION\nOH MY GOD',
    xy=(x[len(x)-1], 1), arrowprops=dict(arrowstyle='->'), xytext=(x[len(x)-4], 45))

plt.title("Hours of my life irretrievably lost")
ax.legend(loc='best')
plt.show()
